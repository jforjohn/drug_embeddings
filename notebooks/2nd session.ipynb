# %%
import sys; sys.path.append('../src')

from input_output.parser import Parser
from input_output.writer import Writer
from preprocessing.tokenizer import tokenize
from preprocessing.transformations import CRF_get_tag, CRFfeatureTransformer

from models.crf import CRFClassifier
from structs import DrugEntity

# %%
bank_type = 'DDI'
bank_name = 'DrugBank'
test_dir = f'../resources/Test-{bank_type}/{bank_name}/'
train_dir = f'../resources/Train/{bank_name}/'

out_file_name = 'task9.2_CRF1_1.txt'
out_folder = '../out/'
out_file = f'{out_folder}{out_file_name}'

# %%
train = Parser(train_dir).call()

train['tokens'] = train['sentence'].apply(tokenize)
train['crf_features'] = train['tokens'].apply(CRFfeatureTransformer().fit_transform)
train['crf_tags'] = train[['tokens', 'parsed_drugs']].apply(CRF_get_tag, axis=1)

# %%
train.head()
# Out:
#                     id                                           sentence  \
# 0  DDI-DrugBank.d25.s0  Corticotropin may accentuate the electrolyte l...
# 1   DDI-DrugBank.d7.s0  The rate of metabolism and the leukopenic acti...
# 2   DDI-DrugBank.d7.s1  The physician should be alert for possible com...
# 3   DDI-DrugBank.d7.s2  Cyclophosphamide treatment, which causes a mar...
# 4   DDI-DrugBank.d7.s3  If a patient has been treated with cyclophosph...
#
#                                         parsed_drugs  \
# 0  [<DrugEntity DDI-DrugBank.d25.s0.e0 0-12 Corti...
# 1  [<DrugEntity DDI-DrugBank.d7.s0.e0 54-69 cyclo...
# 2  [<DrugEntity DDI-DrugBank.d7.s1.e0 102-117 cyc...
# 3  [<DrugEntity DDI-DrugBank.d7.s2.e0 0-15 Cyclop...
# 4  [<DrugEntity DDI-DrugBank.d7.s3.e0 35-50 cyclo...
#
#                                         parsed_pairs  \
# 0  [<DrugPair DDI-DrugBank.d25.s0.p0 DDI-DrugBank...
# 1  [<DrugPair DDI-DrugBank.d7.s0.p0 DDI-DrugBank....
# 2  [<DrugPair DDI-DrugBank.d7.s1.p0 DDI-DrugBank....
# 3  [<DrugPair DDI-DrugBank.d7.s2.p0 DDI-DrugBank....
# 4                                                 []
#
#                                               tokens  \
# 0  [{'text': 'Corticotropin', 'char_offset': [0, ...
# 1  [{'text': 'The', 'char_offset': [0, 2]}, {'tex...
# 2  [{'text': 'The', 'char_offset': [0, 2]}, {'tex...
# 3  [{'text': 'Cyclophosphamide', 'char_offset': [...
# 4  [{'text': 'If', 'char_offset': [0, 1]}, {'text...
#
#                                         crf_features  \
# 0  [{'form': 'Corticotropin', 'form_lower': 'cort...
# 1  [{'form': 'The', 'form_lower': 'the', 'suf3': ...
# 2  [{'form': 'The', 'form_lower': 'the', 'suf3': ...
# 3  [{'form': 'Cyclophosphamide', 'form_lower': 'c...
# 4  [{'form': 'If', 'form_lower': 'if', 'suf3': 'I...
#
#                                             crf_tags
# 0        [B-drug, O, O, O, O, O, O, O, B-drug, O, O]
# 1  [O, O, O, O, O, O, O, O, O, B-drug, O, O, O, O...
# 2  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 3  [B-drug, O, O, O, O, O, O, O, O, O, O, O, O, O...
# 4  [O, O, O, O, O, O, O, B-drug, O, O, O, O, O, O...

# %%
test = Parser(test_dir).call()

test['tokens'] = test['sentence'].apply(tokenize)
test['crf_features'] = test['tokens'].apply(CRFfeatureTransformer().fit_transform)

# %%
test.head()
# Out:
#                      id                                           sentence  \
# 0  DDI-DrugBank.d696.s0  Methysergide may reverse the analgesic activit...
# 1  DDI-DrugBank.d696.s1  Concurrent use with vasoconstrictor agents inc...
# 2  DDI-DrugBank.d756.s0  Dosages of concomitantly administered opioids ...
# 3  DDI-DrugBank.d756.s1  Combination with tramadol (Ultram) is associat...
# 4  DDI-DrugBank.d756.s2  Additive sedative effects and confusional stat...
#
#                                         parsed_drugs  \
# 0  [<DrugEntity DDI-DrugBank.d696.s0.e0 0-11 Meth...
# 1  [<DrugEntity DDI-DrugBank.d696.s1.e0 20-41 vas...
# 2  [<DrugEntity DDI-DrugBank.d756.s0.e0 38-44 opi...
# 3  [<DrugEntity DDI-DrugBank.d756.s1.e0 17-24 tra...
# 4  [<DrugEntity DDI-DrugBank.d756.s2.e0 63-77 lev...
#
#                                         parsed_pairs  \
# 0  [<DrugPair DDI-DrugBank.d696.s0.p0 DDI-DrugBan...
# 1  [<DrugPair DDI-DrugBank.d696.s1.p0 DDI-DrugBan...
# 2  [<DrugPair DDI-DrugBank.d756.s0.p0 DDI-DrugBan...
# 3  [<DrugPair DDI-DrugBank.d756.s1.p0 DDI-DrugBan...
# 4  [<DrugPair DDI-DrugBank.d756.s2.p0 DDI-DrugBan...
#
#                                               tokens  \
# 0  [{'text': 'Methysergide', 'char_offset': [0, 1...
# 1  [{'text': 'Concurrent', 'char_offset': [0, 9]}...
# 2  [{'text': 'Dosages', 'char_offset': [0, 6]}, {...
# 3  [{'text': 'Combination', 'char_offset': [0, 10...
# 4  [{'text': 'Additive', 'char_offset': [0, 7]}, ...
#
#                                         crf_features
# 0  [{'form': 'Methysergide', 'form_lower': 'methy...
# 1  [{'form': 'Concurrent', 'form_lower': 'concurr...
# 2  [{'form': 'Dosages', 'form_lower': 'dosages', ...
# 3  [{'form': 'Combination', 'form_lower': 'combin...
# 4  [{'form': 'Additive', 'form_lower': 'additive'...

# %%
clf = CRFClassifier().fit(train['crf_features'], train['crf_tags'])
test['crf_tags'] = clf.predict(test['crf_features'])

# %%
drugs = []
for tokens, crf_tags in zip(test['tokens'], test['crf_tags']):
    current_drugs = []
    current_token = None
    for token, crf_tag in zip(tokens, crf_tags):
        if crf_tag == 'O':
            if current_token is not None:
                current_drugs.append(current_token)
                current_token = None
        else:
            if current_token == None:
                current_token = DrugEntity(
                    offsets=token['char_offset'],
                    de_type=crf_tag.split('-')[-1],
                    text=token['text']
                )
            else:
                current_token.offsets = [current_token.offsets[0], token['char_offset'][1]]
                current_token.text = current_token.text + ' ' + token['text']

    drugs.append(current_drugs)

test['drugs'] = drugs

# %%
test.head()
# Out:
#                      id                                           sentence  \
# 0  DDI-DrugBank.d696.s0  Methysergide may reverse the analgesic activit...
# 1  DDI-DrugBank.d696.s1  Concurrent use with vasoconstrictor agents inc...
# 2  DDI-DrugBank.d756.s0  Dosages of concomitantly administered opioids ...
# 3  DDI-DrugBank.d756.s1  Combination with tramadol (Ultram) is associat...
# 4  DDI-DrugBank.d756.s2  Additive sedative effects and confusional stat...
#
#                                         parsed_drugs  \
# 0  [<DrugEntity DDI-DrugBank.d696.s0.e0 0-11 Meth...
# 1  [<DrugEntity DDI-DrugBank.d696.s1.e0 20-41 vas...
# 2  [<DrugEntity DDI-DrugBank.d756.s0.e0 38-44 opi...
# 3  [<DrugEntity DDI-DrugBank.d756.s1.e0 17-24 tra...
# 4  [<DrugEntity DDI-DrugBank.d756.s2.e0 63-77 lev...
#
#                                         parsed_pairs  \
# 0  [<DrugPair DDI-DrugBank.d696.s0.p0 DDI-DrugBan...
# 1  [<DrugPair DDI-DrugBank.d696.s1.p0 DDI-DrugBan...
# 2  [<DrugPair DDI-DrugBank.d756.s0.p0 DDI-DrugBan...
# 3  [<DrugPair DDI-DrugBank.d756.s1.p0 DDI-DrugBan...
# 4  [<DrugPair DDI-DrugBank.d756.s2.p0 DDI-DrugBan...
#
#                                               tokens  \
# 0  [{'text': 'Methysergide', 'char_offset': [0, 1...
# 1  [{'text': 'Concurrent', 'char_offset': [0, 9]}...
# 2  [{'text': 'Dosages', 'char_offset': [0, 6]}, {...
# 3  [{'text': 'Combination', 'char_offset': [0, 10...
# 4  [{'text': 'Additive', 'char_offset': [0, 7]}, ...
#
#                                         crf_features  \
# 0  [{'form': 'Methysergide', 'form_lower': 'methy...
# 1  [{'form': 'Concurrent', 'form_lower': 'concurr...
# 2  [{'form': 'Dosages', 'form_lower': 'dosages', ...
# 3  [{'form': 'Combination', 'form_lower': 'combin...
# 4  [{'form': 'Additive', 'form_lower': 'additive'...
#
#                                             crf_tags  \
# 0    [B-drug, O, O, O, O, O, O, B-group, I-group, O]
# 1  [O, O, O, B-group, I-group, O, B-group, I-grou...
# 2  [O, O, O, O, B-group, O, O, O, O, O, O, O, O, ...
# 3  [O, O, B-drug, O, B-brand, O, O, O, O, O, O, O...
# 4  [O, O, O, O, O, O, O, O, O, B-drug, O, O, O, B...
#
#                                                drugs
# 0  [<DrugEntity None 0-11 Methysergide drug>, <Dr...
# 1  [<DrugEntity None 20-41 vasoconstrictor agents...
# 2  [<DrugEntity None 38-44 opioids group>, <DrugE...
# 3  [<DrugEntity None 17-24 tramadol drug>, <DrugE...
# 4  [<DrugEntity None 63-77 levomepromazine drug>,...

# %%
Writer(out_file).call(test, col_names=['drugs'])
pass

# %%
results = !java -jar ../bin/evaluateNER.jar {test_dir} {out_file}
# !rm {out_folder}*.log *.txt
print('\n'.join(results[-5:-2]))
# Out:
# MACRO-AVERAGE MEASURES:
# P	R	F1
# 0.71	0.55	0.61
