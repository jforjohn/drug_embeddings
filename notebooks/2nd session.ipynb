# %%
import sys; sys.path.append('../src')

from input_output.parser import Parser
from input_output.writer import Writer
from preprocessing.tokenizer import tokenize
from preprocessing.transformations import CRF_get_tag, CRFfeatureTransformer

from models.crf import CRFClassifier
from structs import DrugEntity

# %%
bank_type = 'DDI'
bank_name = 'DrugBank'
test_dir = f'../resources/Test-{bank_type}/{bank_name}/'
train_dir = f'../resources/Train/{bank_name}/'

out_file_name = 'task9.2_CRF1_1.txt'
out_folder = '../out/'
out_file = f'{out_folder}{out_file_name}'

# %%
train = Parser(train_dir).call()

train['tokens'] = train['sentence'].apply(tokenize)
train['crf_features'] = train['tokens'].apply(CRFfeatureTransformer().fit_transform)
train['crf_tags'] = train[['tokens', 'parsed_drugs']].apply(CRF_get_tag, axis=1)

# %%
train.crf_features[0]
# Out:
# [{'form': 'FLUOTHANE',
#   'form_lower': 'fluothane',
#   'suf3': 'ANE',
#   'suf4': 'HANE',
#   'is_upper': True,
#   'is_title': False,
#   'is_digit': False,
#   'pos_tag': 'NNP',
#   'rule_classification': 'brand',
#   'BoS': True,
#   'next_form': 'augments',
#   'next_form_lower': 'augments',
#   'next_suf3': 'nts',
#   'next_suf4': 'ents',
#   'next_is_upper': False,
#   'next_is_title': False,
#   'next_is_digit': False,
#   'next_pos_tag': 'VBZ',
#   'next_rule_classification': 'group'},
#  {'form': 'augments',
#   'form_lower': 'augments',
#   'suf3': 'nts',
#   'suf4': 'ents',
#   'is_upper': False,
#   'is_title': False,
#   'is_digit': False,
#   'pos_tag': 'VBZ',
#   'rule_classification': 'group',
#   'previous_form': 'FLUOTHANE',
#   'previous_form_lower': 'fluothane',
#   'previous_suf3': 'ANE',
#   'previous_suf4': 'HANE',
#   'previous_is_upper': True,
#   'previous_is_title': False,
#   'previous_is_digit': False,
#   'previous_pos_tag': 'NNP',
#   'previous_rule_classification': 'brand',
#   'next_form': 'the',
#   'next_form_lower': 'the',
#   'next_suf3': 'the',
#   'next_suf4': 'the',
#   'next_is_upper': False,
#   'next_is_title': False,
#   'next_is_digit': False,
#   'next_pos_tag': 'DT'},
#  {'form': 'the',
#   'form_lower': 'the',
#   'suf3': 'the',
#   'suf4': 'the',
#   'is_upper': False,
#   'is_title': False,
#   'is_digit': False,
#   'pos_tag': 'DT',
#   'previous_form': 'augments',
#   'previous_form_lower': 'augments',
#   'previous_suf3': 'nts',
#   'previous_suf4': 'ents',
#   'previous_is_upper': False,
#   'previous_is_title': False,
#   'previous_is_digit': False,
#   'previous_pos_tag': 'VBZ',
#   'previous_rule_classification': 'group',
#   'next_form': 'action',
#   'next_form_lower': 'action',
#   'next_suf3': 'ion',
#   'next_suf4': 'tion',
#   'next_is_upper': False,
#   'next_is_title': False,
#   'next_is_digit': False,
#   'next_pos_tag': 'NN'},
#  {'form': 'action',
#   'form_lower': 'action',
#   'suf3': 'ion',
#   'suf4': 'tion',
#   'is_upper': False,
#   'is_title': False,
#   'is_digit': False,
#   'pos_tag': 'NN',
#   'previous_form': 'the',
#   'previous_form_lower': 'the',
#   'previous_suf3': 'the',
#   'previous_suf4': 'the',
#   'previous_is_upper': False,
#   'previous_is_title': False,
#   'previous_is_digit': False,
#   'previous_pos_tag': 'DT',
#   'next_form': 'of',
#   'next_form_lower': 'of',
#   'next_suf3': 'of',
#   'next_suf4': 'of',
#   'next_is_upper': False,
#   'next_is_title': False,
#   'next_is_digit': False,
#   'next_pos_tag': 'IN'},
#  {'form': 'of',
#   'form_lower': 'of',
#   'suf3': 'of',
#   'suf4': 'of',
#   'is_upper': False,
#   'is_title': False,
#   'is_digit': False,
#   'pos_tag': 'IN',
#   'previous_form': 'action',
#   'previous_form_lower': 'action',
#   'previous_suf3': 'ion',
#   'previous_suf4': 'tion',
#   'previous_is_upper': False,
#   'previous_is_title': False,
#   'previous_is_digit': False,
#   'previous_pos_tag': 'NN',
#   'next_form': 'non-depolarising',
#   'next_form_lower': 'non-depolarising',
#   'next_suf3': 'ing',
#   'next_suf4': 'sing',
#   'next_is_upper': False,
#   'next_is_title': False,
#   'next_is_digit': False,
#   'next_pos_tag': 'JJ'},
#  {'form': 'non-depolarising',
#   'form_lower': 'non-depolarising',
#   'suf3': 'ing',
#   'suf4': 'sing',
#   'is_upper': False,
#   'is_title': False,
#   'is_digit': False,
#   'pos_tag': 'JJ',
#   'previous_form': 'of',
#   'previous_form_lower': 'of',
#   'previous_suf3': 'of',
#   'previous_suf4': 'of',
#   'previous_is_upper': False,
#   'previous_is_title': False,
#   'previous_is_digit': False,
#   'previous_pos_tag': 'IN',
#   'next_form': 'muscle',
#   'next_form_lower': 'muscle',
#   'next_suf3': 'cle',
#   'next_suf4': 'scle',
#   'next_is_upper': False,
#   'next_is_title': False,
#   'next_is_digit': False,
#   'next_pos_tag': 'NN'},
#  {'form': 'muscle',
#   'form_lower': 'muscle',
#   'suf3': 'cle',
#   'suf4': 'scle',
#   'is_upper': False,
#   'is_title': False,
#   'is_digit': False,
#   'pos_tag': 'NN',
#   'previous_form': 'non-depolarising',
#   'previous_form_lower': 'non-depolarising',
#   'previous_suf3': 'ing',
#   'previous_suf4': 'sing',
#   'previous_is_upper': False,
#   'previous_is_title': False,
#   'previous_is_digit': False,
#   'previous_pos_tag': 'JJ',
#   'next_form': 'relaxants',
#   'next_form_lower': 'relaxants',
#   'next_suf3': 'nts',
#   'next_suf4': 'ants',
#   'next_is_upper': False,
#   'next_is_title': False,
#   'next_is_digit': False,
#   'next_pos_tag': 'NNS',
#   'next_rule_classification': 'group'},
#  {'form': 'relaxants',
#   'form_lower': 'relaxants',
#   'suf3': 'nts',
#   'suf4': 'ants',
#   'is_upper': False,
#   'is_title': False,
#   'is_digit': False,
#   'pos_tag': 'NNS',
#   'rule_classification': 'group',
#   'previous_form': 'muscle',
#   'previous_form_lower': 'muscle',
#   'previous_suf3': 'cle',
#   'previous_suf4': 'scle',
#   'previous_is_upper': False,
#   'previous_is_title': False,
#   'previous_is_digit': False,
#   'previous_pos_tag': 'NN',
#   'next_form': 'and',
#   'next_form_lower': 'and',
#   'next_suf3': 'and',
#   'next_suf4': 'and',
#   'next_is_upper': False,
#   'next_is_title': False,
#   'next_is_digit': False,
#   'next_pos_tag': 'CC'},
#  {'form': 'and',
#   'form_lower': 'and',
#   'suf3': 'and',
#   'suf4': 'and',
#   'is_upper': False,
#   'is_title': False,
#   'is_digit': False,
#   'pos_tag': 'CC',
#   'previous_form': 'relaxants',
#   'previous_form_lower': 'relaxants',
#   'previous_suf3': 'nts',
#   'previous_suf4': 'ants',
#   'previous_is_upper': False,
#   'previous_is_title': False,
#   'previous_is_digit': False,
#   'previous_pos_tag': 'NNS',
#   'previous_rule_classification': 'group',
#   'next_form': 'the',
#   'next_form_lower': 'the',
#   'next_suf3': 'the',
#   'next_suf4': 'the',
#   'next_is_upper': False,
#   'next_is_title': False,
#   'next_is_digit': False,
#   'next_pos_tag': 'DT'},
#  {'form': 'the',
#   'form_lower': 'the',
#   'suf3': 'the',
#   'suf4': 'the',
#   'is_upper': False,
#   'is_title': False,
#   'is_digit': False,
#   'pos_tag': 'DT',
#   'previous_form': 'and',
#   'previous_form_lower': 'and',
#   'previous_suf3': 'and',
#   'previous_suf4': 'and',
#   'previous_is_upper': False,
#   'previous_is_title': False,
#   'previous_is_digit': False,
#   'previous_pos_tag': 'CC',
#   'next_form': 'muscle',
#   'next_form_lower': 'muscle',
#   'next_suf3': 'cle',
#   'next_suf4': 'scle',
#   'next_is_upper': False,
#   'next_is_title': False,
#   'next_is_digit': False,
#   'next_pos_tag': 'NN'},
#  {'form': 'muscle',
#   'form_lower': 'muscle',
#   'suf3': 'cle',
#   'suf4': 'scle',
#   'is_upper': False,
#   'is_title': False,
#   'is_digit': False,
#   'pos_tag': 'NN',
#   'previous_form': 'the',
#   'previous_form_lower': 'the',
#   'previous_suf3': 'the',
#   'previous_suf4': 'the',
#   'previous_is_upper': False,
#   'previous_is_title': False,
#   'previous_is_digit': False,
#   'previous_pos_tag': 'DT',
#   'next_form': 'relaxant',
#   'next_form_lower': 'relaxant',
#   'next_suf3': 'ant',
#   'next_suf4': 'xant',
#   'next_is_upper': False,
#   'next_is_title': False,
#   'next_is_digit': False,
#   'next_pos_tag': 'JJ',
#   'next_rule_classification': 'group'},
#  {'form': 'relaxant',
#   'form_lower': 'relaxant',
#   'suf3': 'ant',
#   'suf4': 'xant',
#   'is_upper': False,
#   'is_title': False,
#   'is_digit': False,
#   'pos_tag': 'JJ',
#   'rule_classification': 'group',
#   'previous_form': 'muscle',
#   'previous_form_lower': 'muscle',
#   'previous_suf3': 'cle',
#   'previous_suf4': 'scle',
#   'previous_is_upper': False,
#   'previous_is_title': False,
#   'previous_is_digit': False,
#   'previous_pos_tag': 'NN',
#   'next_form': 'effects',
#   'next_form_lower': 'effects',
#   'next_suf3': 'cts',
#   'next_suf4': 'ects',
#   'next_is_upper': False,
#   'next_is_title': False,
#   'next_is_digit': False,
#   'next_pos_tag': 'NNS'},
#  {'form': 'effects',
#   'form_lower': 'effects',
#   'suf3': 'cts',
#   'suf4': 'ects',
#   'is_upper': False,
#   'is_title': False,
#   'is_digit': False,
#   'pos_tag': 'NNS',
#   'previous_form': 'relaxant',
#   'previous_form_lower': 'relaxant',
#   'previous_suf3': 'ant',
#   'previous_suf4': 'xant',
#   'previous_is_upper': False,
#   'previous_is_title': False,
#   'previous_is_digit': False,
#   'previous_pos_tag': 'JJ',
#   'previous_rule_classification': 'group',
#   'next_form': 'of',
#   'next_form_lower': 'of',
#   'next_suf3': 'of',
#   'next_suf4': 'of',
#   'next_is_upper': False,
#   'next_is_title': False,
#   'next_is_digit': False,
#   'next_pos_tag': 'IN'},
#  {'form': 'of',
#   'form_lower': 'of',
#   'suf3': 'of',
#   'suf4': 'of',
#   'is_upper': False,
#   'is_title': False,
#   'is_digit': False,
#   'pos_tag': 'IN',
#   'previous_form': 'effects',
#   'previous_form_lower': 'effects',
#   'previous_suf3': 'cts',
#   'previous_suf4': 'ects',
#   'previous_is_upper': False,
#   'previous_is_title': False,
#   'previous_is_digit': False,
#   'previous_pos_tag': 'NNS',
#   'next_form': 'aminoglycosides',
#   'next_form_lower': 'aminoglycosides',
#   'next_suf3': 'des',
#   'next_suf4': 'ides',
#   'next_is_upper': False,
#   'next_is_title': False,
#   'next_is_digit': False,
#   'next_pos_tag': 'NNS',
#   'next_rule_classification': 'group'},
#  {'form': 'aminoglycosides',
#   'form_lower': 'aminoglycosides',
#   'suf3': 'des',
#   'suf4': 'ides',
#   'is_upper': False,
#   'is_title': False,
#   'is_digit': False,
#   'pos_tag': 'NNS',
#   'rule_classification': 'group',
#   'previous_form': 'of',
#   'previous_form_lower': 'of',
#   'previous_suf3': 'of',
#   'previous_suf4': 'of',
#   'previous_is_upper': False,
#   'previous_is_title': False,
#   'previous_is_digit': False,
#   'previous_pos_tag': 'IN',
#   'next_form': '.',
#   'next_form_lower': '.',
#   'next_suf3': '.',
#   'next_suf4': '.',
#   'next_is_upper': False,
#   'next_is_title': False,
#   'next_is_digit': False,
#   'next_pos_tag': '.'},
#  {'form': '.',
#   'form_lower': '.',
#   'suf3': '.',
#   'suf4': '.',
#   'is_upper': False,
#   'is_title': False,
#   'is_digit': False,
#   'pos_tag': '.',
#   'previous_form': 'aminoglycosides',
#   'previous_form_lower': 'aminoglycosides',
#   'previous_suf3': 'des',
#   'previous_suf4': 'ides',
#   'previous_is_upper': False,
#   'previous_is_title': False,
#   'previous_is_digit': False,
#   'previous_pos_tag': 'NNS',
#   'previous_rule_classification': 'group',
#   'EoS': True}]

# %%
test = Parser(test_dir).call()

test['tokens'] = test['sentence'].apply(tokenize)
test['crf_features'] = test['tokens'].apply(CRFfeatureTransformer().fit_transform)

# %%
test.head()
# Out:
#                      id                                           sentence  \
# 0  DDI-DrugBank.d635.s0  Other short-acting beta adrenergic aerosol bro...
# 1  DDI-DrugBank.d703.s0  Interaction with Other Central Nervous System ...
# 2  DDI-DrugBank.d703.s1  RESPIRATORY DEPRESSION, HYPOTENSION, AND PROFO...
# 3  DDI-DrugBank.d712.s0  There have been no formal drug interaction stu...
# 4  DDI-DrugBank.d712.s1  Administration of paclitaxel in combination wi...
#
#                                         parsed_drugs  \
# 0  [<DrugEntity DDI-DrugBank.d635.s0.e0 6-57 shor...
# 1  [<DrugEntity DDI-DrugBank.d703.s0.e0 23-56 Cen...
# 2                                                 []
# 3  [<DrugEntity DDI-DrugBank.d712.s0.e0 66-74 HER...
# 4  [<DrugEntity DDI-DrugBank.d712.s1.e0 18-27 pac...
#
#                                         parsed_pairs  \
# 0  [<DrugPair DDI-DrugBank.d635.s0.p0 DDI-DrugBan...
# 1  [<DrugPair DDI-DrugBank.d703.s0.p0 DDI-DrugBan...
# 2                                                 []
# 3                                                 []
# 4  [<DrugPair DDI-DrugBank.d712.s1.p0 DDI-DrugBan...
#
#                                               tokens  \
# 0  [{'text': 'Other', 'char_offset': [0, 4]}, {'t...
# 1  [{'text': 'Interaction', 'char_offset': [0, 10...
# 2  [{'text': 'RESPIRATORY', 'char_offset': [0, 10...
# 3  [{'text': 'There', 'char_offset': [0, 4]}, {'t...
# 4  [{'text': 'Administration', 'char_offset': [0,...
#
#                                         crf_features
# 0  [{'form': 'Other', 'form_lower': 'other', 'suf...
# 1  [{'form': 'Interaction', 'form_lower': 'intera...
# 2  [{'form': 'RESPIRATORY', 'form_lower': 'respir...
# 3  [{'form': 'There', 'form_lower': 'there', 'suf...
# 4  [{'form': 'Administration', 'form_lower': 'adm...

# %%
clf = CRFClassifier().fit(train['crf_features'], train['crf_tags'])
test['crf_tags'] = clf.predict(test['crf_features'])

# %%
drugs = []
for tokens, crf_tags in zip(test['tokens'], test['crf_tags']):
    current_drugs = []
    current_token = None
    for token, crf_tag in zip(tokens, crf_tags):
        if crf_tag == 'O':
            if current_token is not None:
                current_drugs.append(current_token)
                current_token = None
        else:
            if current_token == None:
                current_token = DrugEntity(
                    offsets=token['char_offset'],
                    de_type=crf_tag.split('-')[-1],
                    text=token['text']
                )
            else:
                current_token.offsets = [current_token.offsets[0], token['char_offset'][1]]
                current_token.text = current_token.text + ' ' + token['text']

    drugs.append(current_drugs)

test['drugs'] = drugs

# %%
test.head()
# Out:
#                      id                                           sentence  \
# 0  DDI-DrugBank.d635.s0  Other short-acting beta adrenergic aerosol bro...
# 1  DDI-DrugBank.d703.s0  Interaction with Other Central Nervous System ...
# 2  DDI-DrugBank.d703.s1  RESPIRATORY DEPRESSION, HYPOTENSION, AND PROFO...
# 3  DDI-DrugBank.d712.s0  There have been no formal drug interaction stu...
# 4  DDI-DrugBank.d712.s1  Administration of paclitaxel in combination wi...
#
#                                         parsed_drugs  \
# 0  [<DrugEntity DDI-DrugBank.d635.s0.e0 6-57 shor...
# 1  [<DrugEntity DDI-DrugBank.d703.s0.e0 23-56 Cen...
# 2                                                 []
# 3  [<DrugEntity DDI-DrugBank.d712.s0.e0 66-74 HER...
# 4  [<DrugEntity DDI-DrugBank.d712.s1.e0 18-27 pac...
#
#                                         parsed_pairs  \
# 0  [<DrugPair DDI-DrugBank.d635.s0.p0 DDI-DrugBan...
# 1  [<DrugPair DDI-DrugBank.d703.s0.p0 DDI-DrugBan...
# 2                                                 []
# 3                                                 []
# 4  [<DrugPair DDI-DrugBank.d712.s1.p0 DDI-DrugBan...
#
#                                               tokens  \
# 0  [{'text': 'Other', 'char_offset': [0, 4]}, {'t...
# 1  [{'text': 'Interaction', 'char_offset': [0, 10...
# 2  [{'text': 'RESPIRATORY', 'char_offset': [0, 10...
# 3  [{'text': 'There', 'char_offset': [0, 4]}, {'t...
# 4  [{'text': 'Administration', 'char_offset': [0,...
#
#                                         crf_features  \
# 0  [{'form': 'Other', 'form_lower': 'other', 'suf...
# 1  [{'form': 'Interaction', 'form_lower': 'intera...
# 2  [{'form': 'RESPIRATORY', 'form_lower': 'respir...
# 3  [{'form': 'There', 'form_lower': 'there', 'suf...
# 4  [{'form': 'Administration', 'form_lower': 'adm...
#
#                                             crf_tags  \
# 0  [O, O, O, O, O, B-group, O, O, O, O, O, O, O, ...
# 1  [O, O, O, B-group, I-group, I-group, I-group, ...
# 2            [O, O, O, O, O, O, O, O, O, O, O, O, O]
# 3   [O, O, O, O, O, O, O, O, O, O, B-brand, O, O, O]
# 4  [O, O, B-drug, O, O, O, B-brand, O, O, O, O, O...
#
#                                                drugs
# 0    [<DrugEntity None 43-57 bronchodilators group>]
# 1  [<DrugEntity None 23-56 Central Nervous System...
# 2                                                 []
# 3          [<DrugEntity None 66-74 HERCEPTIN brand>]
# 4  [<DrugEntity None 18-27 paclitaxel drug>, <Dru...

# %%
Writer(out_file).call(test, col_names=['drugs'])
pass

# %%
results = !java -jar ../bin/evaluateNER.jar {test_dir} {out_file}
# !rm {out_folder}*.log *.txt
print('\n'.join(results[-5:-2]))
# Out:
# MACRO-AVERAGE MEASURES:
# P	R	F1
# 0.71	0.58	0.63
